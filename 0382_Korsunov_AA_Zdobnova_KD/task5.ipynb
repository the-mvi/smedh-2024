# %% [markdown]
# # Практическая работа №5: Элементы регрессионного анализа. Выборочные прямые среднеквадратической регрессии. Корреляционные отношения
#
# Выполнили студенты гр. 0382 Корсунов Антон и Здобнова Ксения. Вариант №11

# %% [markdown]
# ## Цель работы
#
# Ознакомление с основными положениями метода наименьших квадратов (МНК), со статистическими свойствами МНК оценок, с понятием функции регрессии и роли МНК в регрессионном анализе, с корреляционным отношением, как мерой тесноты произвольной (в том числе и линейной) корреляционной связи.

# %% [markdown]
# ## Основные теоретические положения
#
# **Метод наименьших квадратов (МНК)** - метод, основанный на поиске минимума суммы квадратов отклонений значений некоторых функций от заданного множества значений. МНК является одним из основных методов регрессионного анализа и применяется для оценки параметров регрессионных моделей на основе выборочных данных
#
# $$M(X/y)=q_1(y)$$
# $$M(Y/x)=q_2(x)$$
# ****
# Пусть имеется двумерная случайная величина $\{X,Y\}$, где $X$ и $Y$ зависимые случайные величины.
#
# И $Y$ как линейную функцию случайной величины $X$:
# $$Y ≃ g(x) = ax + b$$
# Значения коэффициентов $a$ и $b$ определяются с помощью МНК из условия минимума функции
# $$F(a,b) = m[(Y-aX-b)^2]$$
# В этом случае функцию $g(x)$ называют **линейной функцией среднеквадратической регрессии $Y$ на $X$**
# $$g(x) = m(Y/x) = m(Y)+r_{xy}\frac{σ_y}{σ_x}[x-m(X)]$$
#
# Коэффициент $ρ_{yx}=r_{xy}\frac{σ_y}{σ_x}$ называют **коэффициентом регрессии $Y$ на $X$**
#
# Минимальное значение функции $F(a,b)$ равно $σ_y^2(1-r_{xy}^2)$ и называется **остаточной дисперсией случаной величины $Y$ относительно случайной величины $X$**
#
# Линейная функция среднеквадратической регрессии $X$ на $Y$ строится аналогично:
# $$g(y) = m(X/y) = m(X)+r_{xy}\frac{σ_x}{σ_y}[y-m(Y)]$$
# $ρ_{xy}=r_{xy}\frac{σ_x}{σ_y}$ - коэффициент регрессии $X$ на $Y$, остаточная дисперсия равна $σ_x^2(1-r_{xy}^2)$
#
# ****
# В случае, когда известны только выборочные данные - двумерная выборка значений случайных величин X и Y, возможно построение только выборочных прямых среднеквадратической регрессии. Уравнения выборочных прямых среднеквадратической регрессии получаются на основе уравнений линейных среднеквадратичных регрессий, записанных ранее, в которых все параметры распределений заменяются их статистическими оценками:
# $$\bar y_x = \bar y_в + \bar r_{xy}\frac{S_y}{S_x}(x-\bar x_в)$$
# $$\bar x_y = \bar x_в + \bar r_{xy}\frac{S_x}{S_y}(y-\bar y_в)$$
# ****
# Оценку **общей дисперсии** $X$ можно представить как сумму внутригрупповой и межгрупповой дисперсий:
# $$D_{общ}=D_{межгр}+D_{внгр}$$
# где $D_{внгр}$ - **внутригрупповая дисперсия**, определяемая как взвешенной по объемам групп средняя арифметическая групповых дисперсий
#
# $D_{межгр}$ - **межгрупповая дисперсия**, определяемая как дисперсия условных (групповых) средних $\bar x_{y_i}$ относительно выборочной средней $\bar x_в$
#
# Если $D_{межгр} = 0$, то значит, что все условные (групповые) средние равны и не зависят от выборочных значений $y$. В этом случае выборочные данные не дают оснований предположить, что между исследуемыми случайными величинами имеет место корреляционная зависимость.
#
# Если $D_{внгр} = 0$, то значит, что в каждой из групп имеется только одно значение $X$. В этом случае выборочные данные позволяют предположить наличие функциональной зависимости между исследуемыми случайными величинами
#
# ****
# **Выборочное корреляционное отношение $X$ к $Y$** определяется выражением:
# $$\bar \eta_{xy} = \frac{\bar \sigma_{\bar x_y}}{\bar \sigma_x}$$
# где $\bar \sigma _{\bar x_y} = \sqrt{D_{межгр}}$
#
# $\bar \sigma_x = \sqrt{D_{общ}}$ - выборочные значения СКВО $\bar x_y$ и $X$ соответсвенно
#
# Аналогично определяется выборочное корреляционное отношение $Y$ к $X$:
# $$\bar \eta_{yx} = \frac{\bar \sigma_{\bar y_x}}{\bar \sigma_y}$$
# как для $\bar \eta_{xy}$ так и для $\bar \eta_{yx}$ имеет место равенство:
# $$D_{внгр} = D_{общ}(1-\frac{D_{межгр}}{D_{общ}}) = D_{общ}(1-\eta^2)$$
# ****
# Свойства выборочного корреляционного отношения (имеют место как для $\bar \eta_{xy}$ так и для $\bar \eta_{yx}$):
#
#
# 1.   $0 ≤ \bar \eta ≤ 1$
# 2.   $\bar \eta = 0$ - выборочные данные согласованы с предположением, что случайные величины $X$ и $Y$ не связаны корреляционной зависимостью
# 3. $\bar \eta = 1$ - выборочные данные согласованы с предположением, что случайные величины $X$ и $Y$ связаны функциональной зависимостью
# 4. $\bar \eta \geq |\bar r_{xy}|$
# 5. $\bar \eta = |\bar r_{xy}|$ - выборочные данные согласованы с предположением, что случайные величины  $X$ и $Y$ связаны линейной корреляционной зависимостью
# 6. Корреляционное отношение является количественной мерой тесноты корреляционной зависимости между случайными величинами  $X$ и $Y$. Вместе с тем, кроме п.5, оно не позволяет определить характер корреляционной зависимости
# ****
# Пусть выборочное уравнение регрессии $Y$ на $X$ имеет слудющий вид:
# $$\bar y_x = ax^2 +bx + c$$
# Значения коэффициентов $a,b$ и $c$ можно определить с помощью МНК, что приводит к необходимости решения системый линейных уравнений третьего порядка:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Постановка задачи
#
# Для заданной надежности определить (на основании выборочных данных и результатов выполнения практической работы №2) границы доверительных интервалов для математического ожидания и среднеквадратичного отклонения случайной величины. Проверить гипотезу о нормальном распределении исследуемой случайной величины с помощью критерия Пирсона $\chi^2$. Дать содержательную интерпретацию полученным результатам.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# **Пункт 1**
#
# **Отобразить двумерную выборку на графике.**

# %%
import math #подключение библиотек
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1250, 1230, 1400, 1561, 1391, 1313, 1227, 1773, 1656, 1712, #выборка
                  2005, 1879, 1862, 2158, 1814, 1884, 1504, 1481, 1330, 2109,
                  2164, 1518, 1477, 1626, 1962, 1950, 1148, 1133, 1040, 1954,
                  1604, 1706, 1691, 1488, 1818, 1668, 1380, 1362, 1648, 1696,
                  1492, 2398, 1304, 1886, 1924, 1960, 2008, 1509, 1491, 1431,
                  1843, 1559, 1727, 1655, 1790, 1426, 1334, 1364, 1892, 1335,
                  1939, 1815, 1632, 1420, 1519, 2186, 1569, 1291, 1731, 1355,
                  1166, 1500, 1741, 2021, 1372, 1471, 1391, 1999, 2301, 1663,
                  2052, 1221, 1618, 1287, 2212, 1613, 1370, 2033, 1367, 1569,
                  1350, 1907, 1669, 1646, 1689, 1590, 1442, 1870, 1538, 1787,
                  1536, 1599, 1372, 1075, 1500, 1617, 1840, 1653]
y = [52, 7, 44, 57, 57, 90, 51, 28, 124, 66, 32, 59, 99, 44, 101,
                   21, 63, 41, 44, 62, 66, 30, 104, 28, 35, 68, 35, 71, 77, 36,
                   144, 85, 40, 37, 85, 36, 66, 66, 80, 53, 28, 69, 53, 59, 88,
                   53, 80, 50, 94, 22, 132, 23, 111, 69, 81, 92, 19, 110, 51,
                   76, 39, 92, 121, 38, 104, 79, 50, 31, 60, 37, 14, 33, 16,
                   45, 63, 51, 20, 49, 32, 138, 76, 26, 43, 90, 26, 96, 48,
                   114, 64, 9, 74, 68, 126, 63, 36, 75, 2, 44, 88, 20, 58,
                   9, 40, 32, 16, 35, 88, 39]

plt.scatter(x, y, color='blue', label='Выборка')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Двумерная выборка')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Пункт 2**
#
# **Для заданной выборки построить уравнения средней квадратичной регрессии $x$ на $y$ и $y$ на $x$ соответственно. Построить полученные прямые на множестве выборки. Объяснить результаты.**

# %% [markdown]
# Уравнения средней квадратичной регрессии $y$ на $x$ и $x$ на $y$ соответственн:
# $$\bar y_x = \bar y_в + \bar r_{xy}\frac{S_y}{S_x}(x-\bar x_в)$$
# $$\bar x_y = \bar x_в + \bar r_{xy}\frac{S_x}{S_y}(y-\bar y_в)$$
# ****

# %%
x_mean = 1635.172839506173 # данные из прошлых работ
y_mean = 59.12139917695473
r_xy = 0.14285317064174552
s_x = 286.0932746391938
s_y = 30.86359609429004

# %% [markdown]
# Подставление данных в уравнения:
#
# $\bar y_x = 59.12139917695473 + 0.14285317064174552 \frac{30.86359609429004}{286.0932746391938}(x - 1635.172839506173)$
#
# $\bar x_y = 1635.172839506173 + 0.14285317064174552 \frac{286.0932746391938}{30.86359609429004}(y - 59.12139917695473)$

# %%
y_eq = [y_mean-x_mean*r_xy*s_y/s_x, r_xy*s_y/s_x]
x_eq = [x_mean-y_mean*r_xy*s_x/s_y, r_xy*s_x/s_y]

print('y_x = ' + str(y_eq[1]) + 'x + ' + str(y_eq[0]))
print('x_y = ' + str(x_eq[1]) + 'y + ' + str(x_eq[0]))
# Out:
# y_x = 0.01541092696092169x + 33.92186997884218
# x_y = 1.3241921406899697y + 1556.884747369455

# %% [markdown]
# То есть, уравнения принимают следующий вид:
#
# $\bar y_x = 0.01541092696092169x + 33.92186997884218$
#
# $\bar x_y = 1.3241921406899697y + 1556.884747369455$

# %%
x = [1250, 1230, 1400, 1561, 1391, 1313, 1227, 1773, 1656, 1712, #выборка
                  2005, 1879, 1862, 2158, 1814, 1884, 1504, 1481, 1330, 2109,
                  2164, 1518, 1477, 1626, 1962, 1950, 1148, 1133, 1040, 1954,
                  1604, 1706, 1691, 1488, 1818, 1668, 1380, 1362, 1648, 1696,
                  1492, 2398, 1304, 1886, 1924, 1960, 2008, 1509, 1491, 1431,
                  1843, 1559, 1727, 1655, 1790, 1426, 1334, 1364, 1892, 1335,
                  1939, 1815, 1632, 1420, 1519, 2186, 1569, 1291, 1731, 1355,
                  1166, 1500, 1741, 2021, 1372, 1471, 1391, 1999, 2301, 1663,
                  2052, 1221, 1618, 1287, 2212, 1613, 1370, 2033, 1367, 1569,
                  1350, 1907, 1669, 1646, 1689, 1590, 1442, 1870, 1538, 1787,
                  1536, 1599, 1372, 1075, 1500, 1617, 1840, 1653]
y = [52, 7, 44, 57, 57, 90, 51, 28, 124, 66, 32, 59, 99, 44, 101,
                   21, 63, 41, 44, 62, 66, 30, 104, 28, 35, 68, 35, 71, 77, 36,
                   144, 85, 40, 37, 85, 36, 66, 66, 80, 53, 28, 69, 53, 59, 88,
                   53, 80, 50, 94, 22, 132, 23, 111, 69, 81, 92, 19, 110, 51,
                   76, 39, 92, 121, 38, 104, 79, 50, 31, 60, 37, 14, 33, 16,
                   45, 63, 51, 20, 49, 32, 138, 76, 26, 43, 90, 26, 96, 48,
                   114, 64, 9, 74, 68, 126, 63, 36, 75, 2, 44, 88, 20, 58,
                   9, 40, 32, 16, 35, 88, 39]

x_sample = x.copy()
y_sample = y.copy()

x.sort()
y.sort()

y_x_x = [i for i in range(x[0], x[len(x)-1])]
y_x = [x*y_eq[1] + y_eq[0] for x in y_x_x]

x_y_y = [i for i in range(y[0], y[len(y)-1])]
x_y = [y*x_eq[1] + x_eq[0] for y in x_y_y]


plt.plot(y_x_x, y_x, label='y(x)')
plt.plot(x_y, x_y_y, label='x(y)')
plt.scatter(x_sample, y_sample, color='blue', label='Выборка')
plt.scatter(x_mean, y_mean, color='red')



plt.xlabel('X')
plt.ylabel('Y')
plt.title('Двумерная выборка')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Выводы по пункту:**
#
# Как можно заметить, связь между измеряемыми признаками является слабой (что, опять же, было установлено в предыдушей работе, т.к. коэффициент корреляции оказался близким к нулю)
#
# К тому же, можно заметить, что единственная точка пересечения прямых средней квадратичной регрессии является точкой с координатами выборочного среднего для
# каждого из признаков

# %% [markdown]
# **Пункт 3**
#
# **Составить корреляционную таблицу для нахождения выборочного корреляционного отношения. Убедиться, что неравенства $\eta_{xy} \geqslant |r_{xy}|$ и $\eta_{yx} \geqslant |r_{xy}|$ выполняются.**

# %%
x = [1250, 1230, 1400, 1561, 1391, 1313, 1227, 1773, 1656, 1712, #выборка
                  2005, 1879, 1862, 2158, 1814, 1884, 1504, 1481, 1330, 2109,
                  2164, 1518, 1477, 1626, 1962, 1950, 1148, 1133, 1040, 1954,
                  1604, 1706, 1691, 1488, 1818, 1668, 1380, 1362, 1648, 1696,
                  1492, 2398, 1304, 1886, 1924, 1960, 2008, 1509, 1491, 1431,
                  1843, 1559, 1727, 1655, 1790, 1426, 1334, 1364, 1892, 1335,
                  1939, 1815, 1632, 1420, 1519, 2186, 1569, 1291, 1731, 1355,
                  1166, 1500, 1741, 2021, 1372, 1471, 1391, 1999, 2301, 1663,
                  2052, 1221, 1618, 1287, 2212, 1613, 1370, 2033, 1367, 1569,
                  1350, 1907, 1669, 1646, 1689, 1590, 1442, 1870, 1538, 1787,
                  1536, 1599, 1372, 1075, 1500, 1617, 1840, 1653]
y = [52, 7, 44, 57, 57, 90, 51, 28, 124, 66, 32, 59, 99, 44, 101,
                   21, 63, 41, 44, 62, 66, 30, 104, 28, 35, 68, 35, 71, 77, 36,
                   144, 85, 40, 37, 85, 36, 66, 66, 80, 53, 28, 69, 53, 59, 88,
                   53, 80, 50, 94, 22, 132, 23, 111, 69, 81, 92, 19, 110, 51,
                   76, 39, 92, 121, 38, 104, 79, 50, 31, 60, 37, 14, 33, 16,
                   45, 63, 51, 20, 49, 32, 138, 76, 26, 43, 90, 26, 96, 48,
                   114, 64, 9, 74, 68, 126, 63, 36, 75, 2, 44, 88, 20, 58,
                   9, 40, 32, 16, 35, 88, 39]

xy = tuple(zip(x, y))

table = []
for i in range(9):
    table.append([0] * 9)

# интервалы по двум признкам
x_intervals = ((1040.0, 1190.888888888889), (1190.888888888889, 1341.7777777777778),
              (1341.7777777777778, 1492.6666666666665), (1492.6666666666665, 1643.5555555555557),
              (1643.5555555555557, 1794.4444444444443), (1794.4444444444443, 1945.3333333333333),
              (1945.3333333333333, 2096.222222222222), (2096.222222222222, 2247.1111111111113),
              (2247.1111111111113, 2398.0))

y_intervals = ((2.0, 17.77777777777778), (17.77777777777778, 33.55555555555556),
               (33.55555555555556, 49.333333333333336), (49.333333333333336, 65.11111111111111),
               (65.11111111111111, 80.88888888888889), (80.88888888888889, 96.66666666666667),
               (96.66666666666667, 112.44444444444446), (112.44444444444446, 128.22222222222223),
               (128.22222222222223, 144.0))

# подсчитывание частот для двумрного интервального ряда
for i in xy:
  for j in range(len(x_intervals)):
    for m in range(len(y_intervals)):
      if x_intervals[j][0] == 2247.1111111111113 and x_intervals[j][1] == 2398.0 and y_intervals[m][0] != 128.22222222222223 and y_intervals[m][1] != 144.0:
        if x_intervals[j][0] <= i[0] and i[0] <= x_intervals[j][1] and y_intervals[m][0] <= i[1] and i[1] < y_intervals[m][1]:
          table[j][m] += 1
      if x_intervals[j][0] == 2247.1111111111113 and x_intervals[j][1] == 2398.0 and y_intervals[m][0] == 128.22222222222223 and y_intervals[m][1] == 144.0:
        if x_intervals[j][0] <= i[0] and i[0] <= x_intervals[j][1] and y_intervals[m][0] <= i[1] and i[1] <= y_intervals[m][1]:
          table[j][m] += 1
      if x_intervals[j][0] != 2247.1111111111113 and x_intervals[j][1] != 2398.0 and y_intervals[m][0] == 128.22222222222223 and y_intervals[m][1] == 144.0:
        if x_intervals[j][0] <= i[0] and i[0] < x_intervals[j][1] and y_intervals[m][0] <= i[1] and i[1] <= y_intervals[m][1]:
          table[j][m] += 1
      if x_intervals[j][0] != 2247.1111111111113 and x_intervals[j][1] != 2398.0 and y_intervals[m][0] != 128.22222222222223 and y_intervals[m][1] != 144.0:
        if x_intervals[j][0] <= i[0] and i[0] < x_intervals[j][1] and y_intervals[m][0] <= i[1] and i[1] < y_intervals[m][1]:
          table[j][m] += 1

myTable = PrettyTable(["Y\X", "1115.4444444444443", "1266.3333333333335",
                      "1417.2222222222222", "1568.111111111111",
                       "1719.0", "1869.8888888888887",
                       "2020.7777777777778", "2171.666666666667",
                       "2322.5555555555557", "n_y", "x_y_i"])

# середины интервлов
avg_x = (1115.4444444444443, 1266.3333333333335, 1417.2222222222222, 1568.111111111111,
         1719.0, 1869.8888888888887, 2020.7777777777778, 2171.666666666667,
         2322.5555555555557)

avg_y = (9.88888888888889, 25.666666666666668, 41.44444444444444, 57.22222222222223,
         73.0, 88.77777777777777, 104.55555555555557, 120.33333333333334,
         136.11111111111111)

for i in range(len(y_intervals)-1):
 myTable.add_row([avg_y[i],
                  table[i][0], table[i][1], table[i][2], table[i][3], table[i][4],
                  table[i][5], table[i][6], table[i][7], table[i][8],
                  sum(table[i]), sum([avg_x[l]*table[i][l] for l in range(len(avg_x))]) / sum(table[i])])

temp = len(table) - 1
myTable.add_row(["136.11111111111111", table[temp][0], table[temp][1],
                 table[temp][2], table[temp][3], table[temp][4], table[temp][5],
                 table[temp][6], table[temp][7], table[temp][8],
                 sum(table[temp]), sum([avg_x[l]*table[temp][l] for l in range(len(avg_x))]) / sum(table[temp])])

myTable.add_row(["n_x", sum([j[0] for j in [i for i in table]]), sum([j[1] for j in [i for i in table]]),
                 sum([j[2] for j in [i for i in table]]), sum([j[3] for j in [i for i in table]]),
                 sum([j[4] for j in [i for i in table]]), sum([j[5] for j in [i for i in table]]),
                 sum([j[6] for j in [i for i in table]]), sum([j[7] for j in [i for i in table]]),
                 sum([j[8] for j in [i for i in table]]),
                 "N = " + str(sum([sum(j) for j in [i for i in table]])), '-'])

myTable.add_row(['y_x_j', sum([avg_y[l]*table[l][0] for l in range(len(avg_y))]) / sum([j[0] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][1] for l in range(len(avg_y))]) / sum([j[1] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][2] for l in range(len(avg_y))]) / sum([j[2] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][3] for l in range(len(avg_y))]) / sum([j[3] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][4] for l in range(len(avg_y))]) / sum([j[4] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][5] for l in range(len(avg_y))]) / sum([j[5] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][6] for l in range(len(avg_y))]) / sum([j[6] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][7] for l in range(len(avg_y))]) / sum([j[7] for j in [i for i in table]]),
                 sum([avg_y[l]*table[l][8] for l in range(len(avg_y))]) / sum([j[8] for j in [i for i in table]]),
                 '-', '-'])



print(myTable)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+--------------------+-------------------+--------------------+---------+--------------------+
# |        Y\X         | 1115.4444444444443 | 1266.3333333333335 | 1417.2222222222222 | 1568.111111111111  |       1719.0      | 1869.8888888888887 | 2020.7777777777778 | 2171.666666666667 | 2322.5555555555557 |   n_y   |       x_y_i        |
# +--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+--------------------+-------------------+--------------------+---------+--------------------+
# |  9.88888888888889  |         1          |         1          |         1          |         0          |         2         |         0          |         0          |         0         |         0          |    5    |       1447.4       |
# ...

# %% [markdown]
# Т.к. на github таблица может съехать, снизу она была переписана вручную

# %% [markdown]
# | Y\X | 1115.4444444444443 | 1266.3333333333335 | 1417.2222222222222 | 1568.111111111111 | 1719.0 | 1869.8888888888887  | 2020.7777777777778 | 2171.666666666667 | 2322.5555555555557 |  $n_y$ | $\bar X_y$|
# |----------|----------|----------|----------|----------|----------|----------|----------|----------|----------|----------|----------|
# | 9.88888888888889   | 1   | 1   | 1    | 0  | 2   |0    | 0   | 0   | 0    | 5|1447.4|
# | 25.666666666666668      | 1   | 3   | 1    | 3   | 1   | 2   | 0   | 0   | 0   | 11| 1499.5252525252524|
# | 41.44444444444444     | 1   | 3   | 7   | 4  | 3   | 2    | 2   | 0   | 0  | 22| 1547.5353535353536|
# | 57.22222222222223     | 3  | 4  | 2    | 5   | 1   | 2    | 1   | 1   | 1  |20| 1553.0222222222224|
# | 73.0      | 1  | 2  | 4   | 3  | 3   | 2   | 1   | 2   | 1  | 19| 1663.409356725146|
# | 88.77777777777777      | 0   | 1   | 2    | 3   | 1   | 4    | 2   | 0  | 1  | 14| 1740.5555555555552|
# | 104.55555555555557     | 0   | 1   | 4    | 1   | 3   | 0    | 0   | 1   | 0   | 10| 1583.2|
# | 120.33333333333334    | 0   | 1   | 1    | 1   | 2   | 0    | 0   |0   | 0    | 5| 1537.9333333333334|
# | 136.11111111111111     | 0   | 1   | 0    | 0   | 1   | 0    | 0   | 0   | 0   | 2| 1492.6666666666667|
# | $n_x$     | 7   | 17   | 22    | 20   | 17   | 12    | 6   | 4   | 3   | N = 108| -|
# | $\bar Y_x$     | 45.952380952380956   | 60.93464052287582   | 65.82828282828282    | 61.955555555555556   | 72.07189542483661   | 62.48148148148149    | 65.1111111111111   | 76.94444444444446   | 73.0   | -| -|

# %% [markdown]
# Выше выведена корреляционная таблица. Первая строка - середины интервалов первого признака, первый столбец - втоого признака. n_y - суммы частот по строка, $n_x$ - по столбцам. $\bar X_y$ - групповая средняя по первом признаку, $\bar Y_x$ - по второму признаку.

# %%
N = 108

x_y_i = (1447.4, 1499.5252525252524, 1547.5353535353536, 1553.0222222222224, 1663.409356725146,
         1740.5555555555552, 1583.2, 1537.9333333333334, 1492.6666666666667) # групповая средняя по x

n_y = (5, 11, 22, 20, 19, 14, 10, 5, 2) # частоты по строкам

D_x_group = []
for i in range(len(n_y)):
  counter = 0
  for j in range(len(avg_x)):
    counter += (avg_x[j] - x_y_i[i]) ** 2 * table[i][j]
  D_x_group.append(counter / n_y[i])

# внутригрупповая дисперсия x к y
D_xy_in_group = sum([D_x_group[i] * n_y[i] for i in range(len(D_x_group))]) / N

y_x_j = (45.952380952380956, 60.93464052287582, 65.82828282828282, 61.955555555555556,
         72.07189542483661, 62.48148148148149, 65.1111111111111, 76.94444444444446,
         73.0) # групповая средняя по x
n_x = (7, 17, 22, 20, 17, 12, 6, 4, 3) # частоты по столбцам

D_y_group = []
for i in range(len(n_x)):
  counter = 0
  for j in range(len(avg_y)):
    counter += (avg_y[j] - y_x_j[i]) ** 2 * table[j][i]
  D_y_group.append(counter / n_x[i])

# внутригрупповая дисперсия y к x
D_yx_in_group = sum([D_y_group[i] * n_x[i] for i in range(len(D_y_group))]) / N

x_mean = 1635.172839506173 # выборочные средние из прошлых работ
y_mean = 59.12139917695473

D_xy_inter_group = sum([(x_y_i[i]-x_mean) ** 2 * n_y[i] for i in range(len(x_y_i))]) / N
# межгрупповая дисперсия x к y

D_yx_inter_group = sum([(y_x_j[i]-y_mean) ** 2 * n_x[i] for i in range(len(y_x_j))]) / N
# межгрупповая дисперсия y к x

D_xy_general = D_xy_in_group + D_xy_inter_group # общая дисперсия x к y
D_yx_general = D_yx_in_group + D_yx_inter_group # общая дисперсия y к x

eta_xy = math.sqrt(D_xy_inter_group / D_xy_general) # выборочное корреляционное отношение x к y
eta_yx = math.sqrt(D_yx_inter_group / D_yx_general) # выборочное корреляционное отношение y к x

print('Внутригрупповая дисперсия X к Y = ' + str(D_xy_in_group))
print('Внутригрупповая дисперсия Y к X = ' + str(D_yx_in_group))
print('Межгрупповая дисперсия X к Y = ' + str(D_xy_inter_group))
print('Межгрупповая дисперсия Y к X = ' + str(D_yx_inter_group))
print('Выборочное корреляционное отношение X к Y = ' + str(eta_xy))
print('Выборочное корреляционное отношение Y к X = ' + str(eta_yx))
# Out:
# Внутригрупповая дисперсия X к Y = 79739.54329673167
# Внутригрупповая дисперсия Y к X = 843.6236437468948
# Межгрупповая дисперсия X к Y = 8964.529608821344
# Межгрупповая дисперсия Y к X = 69.17136124895617
# Выборочное корреляционное отношение X к Y = 0.31790105734537927
# Выборочное корреляционное отношение Y к X = 0.2752811879471464

# %% [markdown]
# То есть, согласно вычислениям:
#
# $D_{внгр_{xy}} = 79739.54329673167$ (где $D_{внгр}$ - внутригрупповая дисперсия, определяемая как взвешенной по объемам групп средняя арифметическая групповых дисперсий)
#
# $D_{внгр_{yx}} = 843.6236437468948$
#
# $D_{межгр_{xy}} = 8964.529608821344$ (где $D_{межгр}$ - межгрупповая дисперсия, определяемая как дисперсия условных (групповых) средних относительно выборочной средней)
#
# $D_{межгр_{yx}} = 69.17136124895617$
#
# $\eta_{xy} = 0.31790105734537927$ ($\bar \eta_{xy} = \frac{\bar \sigma_{\bar x_y}}{\bar \sigma_x}$
# где $\bar \sigma _{\bar x_y} = \sqrt{D_{межгр}}$, $\bar \sigma_x = \sqrt{D_{общ}}$ - выборочные значения СКВО $\bar x_y$ и $X$ соответсвенно, $D_{общ}=D_{межгр}+D_{внгр}$)
#
# $\eta_{yx} = 0.2752811879471464$

# %% [markdown]
# т.к. $r_{xy} = 0.14285317064174552$
#
# то $\eta_{xy} \geqslant |r_{xy}|$ и $\eta_{yx} \geqslant |r_{xy}|$ выполняются

# %% [markdown]
# **Пункт 4**
#
# **Для заданной выборки построить корреляционную кривую параболического вида $y = \beta_0 + \beta_1x + \beta_2x^2$ , сделать выводы.**

# %% [markdown]
# Значения коэффициентов $β_0 = c, β_1 = b, β_2 = a$ определяются с помощью МНК, что приводит к необходимости решения системы линейных уравнений третьего порядка:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Построение таблицы для упрощения вычислений:

# %%
avg_x = (1115.4444444444443, 1266.3333333333335, 1417.2222222222222, 1568.111111111111, # x
         1719.0, 1869.8888888888887, 2020.7777777777778, 2171.666666666667,
         2322.5555555555557)

n_x = (7, 17, 22, 20, 17, 12, 6, 4, 3) # n_x

y_x_j = (45.952380952380956, 60.93464052287582, 65.82828282828282, 61.955555555555556, # y_x
         72.07189542483661, 62.48148148148149, 65.1111111111111, 76.94444444444446,
         73.0)

n_xx = [avg_x[i] * n_x[i] for i in range(len(avg_x))] # n_x * x
n_xx2 = [avg_x[i] * n_xx[i] for i in range(len(n_xx))] # n_x * x ^ 2
n_xx3 = [avg_x[i] * n_xx2[i] for i in range(len(n_xx2))] # n_x * x ^ 3
n_xx4 = [avg_x[i] * n_xx3[i] for i in range(len(n_xx3))] # n_x * x ^ 4
n_xy_x = [n_x[i] * y_x_j[i] for i in range(len(y_x_j))] # n_x * y_x
n_xy_xx = [n_xy_x[i] * avg_x[i] for i in range(len(n_xy_x))] # n_x * y_x * x
n_xy_xxx = [n_xy_xx[i] * avg_x[i] for i in range(len(n_xy_xx))] # n_x * y_x * x^2



myTable = PrettyTable(["x", "n_x", "y_x", "n_x * x", "n_x * x^2", "n_x * x^3", "n_x * x^4",
                       "n_x * y_x", "n_x * y_x * x", "n_x * y_x * x^2"])

for i in range(len(n_xx)):
  myTable.add_row([avg_x[i], n_x[i], y_x_j[i], n_xx[i], n_xx2[i], n_xx3[i], n_xx4[i], n_xy_x[i], n_xy_xx[i], n_xy_xxx[i]])

myTable.add_row(["sum", sum(n_x), "-", sum(n_xx), sum(n_xx2), sum(n_xx3),
                sum(n_xx4), sum(n_xy_x), sum(n_xy_xx), sum(n_xy_xxx)])

print(myTable)
# Out:
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |         x          | n_x |        y_x         |      n_x * x       |     n_x * x^2      |     n_x * x^3      |     n_x * x^4      |     n_x * y_x      |   n_x * y_x * x    |  n_x * y_x * x^2   |
# +--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# | 1115.4444444444443 |  7  | 45.952380952380956 |  7808.11111111111  | 8709514.160493826  | 9714979184.133057  | 10836519558834.639 | 321.6666666666667  | 358801.2962962963  | 400222912.61316866 |
# | 1266.3333333333335 |  17 | 60.93464052287582  | 21527.666666666668 | 27261201.888888896 | 34521768658.62964  | 43716066378044.67  | 1035.888888888889  |  1311780.62962963  | 1661151537.3209882 |
# ...

# %% [markdown]
# Т.к. на github таблица может съехать, снизу она была переписана вручную

# %% [markdown]
# | x | $n_x$ | $\bar Y_x$ | $n_x x$ | $n_x x^2$ | $n_x x^3$ | $n_x x^4$  | $n_x \bar Y_x$|  $n_x \bar Y_x x$ | $n_x \bar Y_x x^2$ |
# |---------------------|-----|--------------------|--------------------|--------------------|---------------------|------------------------|---------------------|---------------------|----------------------|
# | 1115.4444444444443 | 7   | 45.952380952380956 | 7808.11111111111  | 8709514.160493826  | 9714979184.133057   | 10836519558834.639    | 321.6666666666667  | 358801.2962962963  | 400222912.61316866  |
# | 1266.3333333333335 | 17  | 60.93464052287582  | 21527.666666666668| 27261201.888888896| 34521768658.62964   | 43716066378044.67    | 1035.888888888889  | 1311780.62962963  | 1661151537.3209882  |
# | 1417.2222222222222 | 22  | 65.82828282828282  | 31178.888888888887| 44187414.19753086 | 62623385343.27845   | 88751253339279.62    | 1448.2222222222222 | 2052452.7160493825 | 2908781599.2455416  |
# | 1568.111111111111  | 20  | 61.955555555555556 | 31362.222222222223| 49179449.13580247 | 77118840628.17558   | 120930910865049.11   | 1239.111111111111  | 1943063.9012345679 | 3046940093.1248283  |
# | 1719.0              | 17  | 72.07189542483661  | 29223.0           | 50234337.0         | 86352825303.0       | 148440506695857.0     | 1225.2222222222224 | 2106157.0000000005 | 3620483883.000001   |
# | 1869.8888888888887 | 12  | 62.48148148148149  | 22438.666666666664| 41957813.48148147 | 78456449231.09462   | 146704842678899.03   | 749.7777777777778  | 1402001.135802469  | 2621586346.0466385  |
# | 2020.7777777777778 | 6   | 65.1111111111111   | 12124.666666666668| 24501256.962962966| 49511595598.37861   | 100051932127523.53   | 390.66666666666663 | 789450.5185185184  | 1595304064.4773662  |
# | 2171.666666666667  | 4   | 76.94444444444446  | 8686.666666666668 | 18864544.44444445 | 40967502351.851875  | 88967759274105.0     | 307.7777777777778  | 668390.7407407409  | 1451521891.9753091  |
# | 2322.5555555555557 | 3   | 73.0               | 6967.666666666667 | 16182792.925925927| 37585435614.514404  | 87294262294466.06    | 219.0              | 508639.6666666667  | 1181343883.5925927  |
# | $\sum$                 | 108 | -                  | 171317.55555555553| 281078324.19753087 | 476852781913.0562   | 835694053212058.8    | 6937.333333333334  | 11140737.60493827  | 18487336211.396435  |

# %% [markdown]
# То есть получается следующая система уравнений:
#
# \begin{equation}
# \left\{
# \begin{array}{ll}
# 835694053212058.8a + 476852781913.0562b + 281078324.19753087c = 18487336211.396435\\
# 476852781913.0562a + 281078324.19753087b + 171317.55555555553c = 11140737.60493827\\
# 281078324.19753087a + 171317.55555555553b + 108c = 6937.333333333334\end{array}\right.
# \end{equation}

# %%
##############################
#Решение системы с помощью numpy


left_side = np.array([[835694053212058.8, 476852781913.0562, 281078324.19753087],
 [476852781913.0562, 281078324.19753087, 171317.55555555553],
  [281078324.19753087, 171317.55555555553, 108]])

right_side = np.array([18487336211.396435, 11140737.60493827, 6937.333333333334])

a,b,c = np.linalg.inv(left_side).dot(right_side)

print("a = " + str(a))
print("b = " + str(b))
print("c = " + str(c))
# Out:
# a = -1.746526626867098e-05
# b = 0.07266848047463192
# c = -5.582827157920353

# %% [markdown]
# Тогда корреляционная кривая параболического вида примет вид:
# $$y = -0.00001746526626867098x^2 + 0.07266848047463192x - 5.582827157920353$$

# %%
x = [1250, 1230, 1400, 1561, 1391, 1313, 1227, 1773, 1656, 1712, #выборка
                  2005, 1879, 1862, 2158, 1814, 1884, 1504, 1481, 1330, 2109,
                  2164, 1518, 1477, 1626, 1962, 1950, 1148, 1133, 1040, 1954,
                  1604, 1706, 1691, 1488, 1818, 1668, 1380, 1362, 1648, 1696,
                  1492, 2398, 1304, 1886, 1924, 1960, 2008, 1509, 1491, 1431,
                  1843, 1559, 1727, 1655, 1790, 1426, 1334, 1364, 1892, 1335,
                  1939, 1815, 1632, 1420, 1519, 2186, 1569, 1291, 1731, 1355,
                  1166, 1500, 1741, 2021, 1372, 1471, 1391, 1999, 2301, 1663,
                  2052, 1221, 1618, 1287, 2212, 1613, 1370, 2033, 1367, 1569,
                  1350, 1907, 1669, 1646, 1689, 1590, 1442, 1870, 1538, 1787,
                  1536, 1599, 1372, 1075, 1500, 1617, 1840, 1653]
y = [52, 7, 44, 57, 57, 90, 51, 28, 124, 66, 32, 59, 99, 44, 101,
                   21, 63, 41, 44, 62, 66, 30, 104, 28, 35, 68, 35, 71, 77, 36,
                   144, 85, 40, 37, 85, 36, 66, 66, 80, 53, 28, 69, 53, 59, 88,
                   53, 80, 50, 94, 22, 132, 23, 111, 69, 81, 92, 19, 110, 51,
                   76, 39, 92, 121, 38, 104, 79, 50, 31, 60, 37, 14, 33, 16,
                   45, 63, 51, 20, 49, 32, 138, 76, 26, 43, 90, 26, 96, 48,
                   114, 64, 9, 74, 68, 126, 63, 36, 75, 2, 44, 88, 20, 58,
                   9, 40, 32, 16, 35, 88, 39]

x_sample = x.copy()
y_sample = y.copy()

x.sort()

y_x_x = [i for i in range(x[0], x[len(x)-1])]
y_x = [a*x**2 + b*x + c for x in y_x_x]


plt.plot(y_x_x, y_x, label='y(x) (парабол)')
plt.scatter(x_sample, y_sample, color='blue', label='Выборка')



plt.xlabel('X')
plt.ylabel('Y')
plt.title('Двумерная выборка')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Выводы по пункту:**
#
# После построения кривой на множества выборки визуально можно оценить, что корреляционная зависимость между двумя признаками плохо выражается через параболическую функцию.

# %% [markdown]
# **Пункт 5**
#
# **Для заданной выборки построить корреляционную кривую в зависимости от номера варианта и сделать выводы:**
#
# **e. обратно пропорциональная функция: $y = \beta_0 + \cfrac{\beta_1}x$**

# %% [markdown]
# Значения коэффициентов  $β_0=b,β_1=a$  определяются с помощью МНК, что приводит к необходимости решения системы линейных уравнений:

# %% [markdown]
# \begin{equation}
# \left\{
# \begin{array}{ll}
# (\sum_{i=1}^m\frac{1}{x_i^2})a+(\sum_{i=1}^m\frac{1}{x_i})b = \sum_{i=1}^m\frac{\bar y_{x_i}}{x_i}\\
# (\sum_{i=1}^m\frac{1}{x_i})a + Nb = \sum_{i=1}^m\bar y_{x_i}\end{array}\right.
# \end{equation}

# %% [markdown]
# Построение таблицы для упрощения вычислений:

# %%
avg_x = (1115.4444444444443, 1266.3333333333335, 1417.2222222222222, 1568.111111111111, # x
         1719.0, 1869.8888888888887, 2020.7777777777778, 2171.666666666667,
         2322.5555555555557)

y_x_j = (45.952380952380956, 60.93464052287582, 65.82828282828282, 61.955555555555556, # y_x
         72.07189542483661, 62.48148148148149, 65.1111111111111, 76.94444444444446,
         73.0)

n_xx_rev = [1 / avg_x[i] for i in range(len(avg_x))] # 1 / x
n_xx2_rev = [(1 / avg_x[i]) * n_xx_rev[i] for i in range(len(n_xx_rev))] # 1 / x^2
n_xy_x_rev = [y_x_j[i] / avg_x[i] for i in range(len(y_x_j))] # y_x / n_x



myTable = PrettyTable(["x", "y_x", "1 / x", "1 / x^2",
                       "y_x / x"])

for i in range(len(n_xx_rev)):
  myTable.add_row([avg_x[i], y_x_j[i], n_xx_rev[i], n_xx2_rev[i], n_xy_x_rev[i]])

myTable.add_row(["sum", sum(y_x_j), sum(n_xx_rev), sum(n_xx2_rev), sum(n_xy_x_rev)])

print(myTable)
# Out:
# +--------------------+--------------------+------------------------+------------------------+----------------------+
# |         x          |        y_x         |         1 / x          |        1 / x^2         |       y_x / x        |
# +--------------------+--------------------+------------------------+------------------------+----------------------+
# | 1115.4444444444443 | 45.952380952380956 | 0.0008965036358203009  | 8.037187690390187e-07  | 0.04119647659840907  |
# | 1266.3333333333335 | 60.93464052287582  | 0.0007896814951302973  | 6.235968637512218e-07  | 0.04811895803333178  |
# | 1417.2222222222222 | 65.82828282828282  | 0.0007056056448451588  | 4.978793260373524e-07  | 0.046448807954099995 |
# | 1568.111111111111  | 61.955555555555556 |  0.000637709912846312  | 4.0667393294245084e-07 | 0.03950967193367817  |
# |       1719.0       | 72.07189542483661  | 0.0005817335660267597  | 3.384139418422104e-07  | 0.04192664073579791  |
# ...

# %% [markdown]
# Т.к. на github таблица может съехать, снизу она была переписана вручную

# %% [markdown]
# |         x          |       $ y_x$         |        $ \frac{1}{ x}$          |       $ \frac{1}{ x^2}$       |      $\frac{ y_x}{ x } $      |
# |--------------------|--------------------|------------------------|------------------------|----------------------|
# | 1115.4444444444443 | 45.952380952380956 | 0.0008965036358203009  | 8.037187690390187e-07  | 0.04119647659840907  |
# | 1266.3333333333335 | 60.93464052287582  | 0.0007896814951302973  | 6.235968637512218e-07  | 0.04811895803333178  |
# | 1417.2222222222222 | 65.82828282828282  | 0.0007056056448451588  | 4.978793260373524e-07  | 0.046448807954099995 |
# | 1568.111111111111  | 61.955555555555556 |  0.000637709912846312  | 4.0667393294245084e-07 | 0.03950967193367817  |
# |       1719.0       | 72.07189542483661  | 0.0005817335660267597  | 3.384139418422104e-07  | 0.04192664073579791  |
# | 1869.8888888888887 | 62.48148148148149  | 0.0005347911343514172  | 2.860015573808756e-07  | 0.033414542357438556 |
# | 2020.7777777777778 |  65.1111111111111  | 0.0004948589651949195  | 2.448853954337865e-07  | 0.03222081706713586  |
# | 2171.666666666667  | 76.94444444444446  | 0.00046047582501918644 | 2.120379854271004e-07  | 0.03543105653619852  |
# | 2322.5555555555557 |        73.0        | 0.0004305602066688992  | 1.8538209156676517e-07 | 0.03143089508682964  |
# |        sum         | 584.2797923209687  |  0.005531920385903251  | 3.598589863420782e-06  | 0.34969786630291944  |

# %% [markdown]
# То есть получается следующая система уравнений:
# \begin{equation}
# \left\{
# \begin{array}{ll}
# 0.000003598589863420782a+0.005531920385903251b = 0.34969786630291944\\
# (0.005531920385903251a + 108b = 584.2797923209687\end{array}\right.
# \end{equation}

# %%
##############################
#Решение системы с помощью numpy


left_side = np.array([[0.000003598589863420782, 0.005531920385903251],
  [0.005531920385903251, 108]])

right_side = np.array([0.34969786630291944, 584.2797923209687])

a,b = np.linalg.inv(left_side).dot(right_side)

print("a = " + str(a))
print("b = " + str(b))
# Out:
# a = 96454.70834655325
# b = 0.4694446750214652

# %% [markdown]
# Тогда корреляционная кривая примет вид:
# $$y = 0.4694446750214652 + \frac{96454.70834655325}{x}$$

# %%
x = [1250, 1230, 1400, 1561, 1391, 1313, 1227, 1773, 1656, 1712, #выборка
                  2005, 1879, 1862, 2158, 1814, 1884, 1504, 1481, 1330, 2109,
                  2164, 1518, 1477, 1626, 1962, 1950, 1148, 1133, 1040, 1954,
                  1604, 1706, 1691, 1488, 1818, 1668, 1380, 1362, 1648, 1696,
                  1492, 2398, 1304, 1886, 1924, 1960, 2008, 1509, 1491, 1431,
                  1843, 1559, 1727, 1655, 1790, 1426, 1334, 1364, 1892, 1335,
                  1939, 1815, 1632, 1420, 1519, 2186, 1569, 1291, 1731, 1355,
                  1166, 1500, 1741, 2021, 1372, 1471, 1391, 1999, 2301, 1663,
                  2052, 1221, 1618, 1287, 2212, 1613, 1370, 2033, 1367, 1569,
                  1350, 1907, 1669, 1646, 1689, 1590, 1442, 1870, 1538, 1787,
                  1536, 1599, 1372, 1075, 1500, 1617, 1840, 1653]
y = [52, 7, 44, 57, 57, 90, 51, 28, 124, 66, 32, 59, 99, 44, 101,
                   21, 63, 41, 44, 62, 66, 30, 104, 28, 35, 68, 35, 71, 77, 36,
                   144, 85, 40, 37, 85, 36, 66, 66, 80, 53, 28, 69, 53, 59, 88,
                   53, 80, 50, 94, 22, 132, 23, 111, 69, 81, 92, 19, 110, 51,
                   76, 39, 92, 121, 38, 104, 79, 50, 31, 60, 37, 14, 33, 16,
                   45, 63, 51, 20, 49, 32, 138, 76, 26, 43, 90, 26, 96, 48,
                   114, 64, 9, 74, 68, 126, 63, 36, 75, 2, 44, 88, 20, 58,
                   9, 40, 32, 16, 35, 88, 39]

x_sample = x.copy()
y_sample = y.copy()

x.sort()

y_x_x = [i for i in range(x[0], x[len(x)-1])]
y_x = [b + a/x for x in y_x_x]


plt.plot(y_x_x, y_x, label='y(x) (гиперб)')
plt.scatter(x_sample, y_sample, color='blue', label='Выборка')



plt.xlabel('X')
plt.ylabel('Y')
plt.title('Двумерная выборка')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Выводы по пункту:**

# %% [markdown]
# После построения кривой на множества выборки визуально можно оценить, что, как и в случае с параболической функции, корреляционная зависимость между двумя признаками тоже плохо выражается через гиперболическую функцию.

# %% [markdown]
# ## Выводы
#
# Работа выполнена на языке программирования Python. В ходе решения
# поставленных задач были усвоены такие понятия как метод наименьших квадратов, коэффициентом регрессии, остаточная дисперсия, внутригрупповая, общая и межгрупповая дисперсии, выборочное корреляционное отношение. При построении уравнений средней квадратичной регрессии  x  на  y  и  y  на  x было установлено, что корреляционная связь между двумя исследуемыми признаками является очень слабой (что ранее подтверждалось близким к нулю значением коэффициента корреляции). Далее были найдены корреляционные отношения и проверено, что они численно больше коэффициента корреляции. В конце были построенны корреляционные кривые двух видов (от параболлической функции и от гиперболической функции), обе кривые, как было установлено визуально, плохо отражают зависимость между двумя признаками.
